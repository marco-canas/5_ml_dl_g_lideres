# %% [markdown]
# # Machine Learning y Deep Learning con Python
# ## Programa G-Líderes – Administración de Empresas
# **Universidad de Antioquia – Campus Caucasia**
#
# **Profesor:** Marco Julio
#
# ---
# Este cuaderno sirve como **formato base para todas las clases del curso**.
# Cada sesión incluye: explicación conceptual, actividad práctica, evaluación formativa y tareas.
#
# **Aviso importante:** El curso contará con **horarios de asesoría presencial** con el profesor Marco Julio, orientados a apoyar el desarrollo de las actividades, resolver dudas y garantizar el logro de los objetivos de aprendizaje.

# %% [markdown]
# ## Clase X – Título de la clase
#
# ### Objetivos de aprendizaje
# - Objetivo 1
# - Objetivo 2
#
# ### Contexto administrativo
# Breve descripción del problema empresarial o de liderazgo que se abordará en la sesión.

# %% [markdown]
# ### Contenidos clave
# - Concepto 1
# - Concepto 2
# - Relación con la toma de decisiones estratégicas

# %% [markdown]
# ## Actividad práctica guiada
# En esta sección el estudiante desarrolla paso a paso la actividad propuesta, utilizando datos reales o simulados del contexto administrativo.

# %%
# Espacio para código en Python
# El estudiante debe ejecutar, modificar e interpretar los resultados

import pandas as pd
import numpy as np

# Cargar o simular datos
datos = pd.DataFrame({
    'ventas': np.random.randint(100, 500, 10),
    'costos': np.random.randint(50, 300, 10)
})

datos

# %% [markdown]
# ### Preguntas de análisis
# 1. ¿Qué información relevante se obtiene de los datos?
# 2. ¿Cómo apoyarían estos resultados una decisión administrativa?
# 3. ¿Qué limitaciones observas en el análisis realizado?

# %% [markdown]
# ## Evaluación formativa (en clase)
# - Explica con tus propias palabras el concepto trabajado.
# - Interpreta los resultados obtenidos en el ejercicio práctico.
# - Relaciona el análisis con un contexto real de empresa o emprendimiento.

# %% [markdown]
# ## Tarea para la próxima sesión
# - Replicar el análisis con un nuevo conjunto de datos.
# - Formular una pregunta estratégica que pueda resolverse con datos.
# - Subir el cuaderno resuelto a GitHub o a la plataforma indicada.

# %% [markdown]
# ## Acompañamiento y asesoría
# **Horario de asesoría presencial:**
#
# El profesor **Marco Julio** dispondrá de un espacio semanal de asesoría presencial en el Campus Caucasia, orientado a:
# - Resolver dudas conceptuales y técnicas.
# - Acompañar el desarrollo de las tareas.
# - Apoyar el logro de los objetivos de aprendizaje de la clase.
#
# *Se recomienda a los estudiantes asistir activamente a estos espacios de acompañamiento.*

# %% [markdown]
# ---
# ### Reflexión final del estudiante
# ¿Qué aprendí en esta clase y cómo lo puedo aplicar en mi formación como administrador(a) y líder?
