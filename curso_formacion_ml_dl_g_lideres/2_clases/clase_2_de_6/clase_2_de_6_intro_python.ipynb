# %% [markdown]
# A continuación tienes un **diseño de clase completo** para una sesión inicial orientada a estudiantes de Administración de Empresas, integrando alfabetización digital, herramientas de desarrollo y fundamentos de Python con aplicaciones empresariales.
#
# ---
#
# ## Diseño de clase
#
# **Tema:** Introducción al ecosistema digital, Colab/VS Code, sintaxis básica de Python y ejercicios aplicados a la administración de empresas
# **Duración estimada:** 3 horas
# **Modalidad:** Taller práctico (enfoque flipped classroom + aprendizaje basado en problemas)
# **Población:** Estudiantes de Administración de Empresas sin experiencia previa en programación
#
# ---
#
# ## 1. Propósito formativo
#
# Introducir a los estudiantes en el ecosistema digital de trabajo para ciencia de datos y análisis empresarial, familiarizándolos con Google Colab y VS Code, y desarrollando competencias iniciales en la sintaxis básica de Python mediante problemas contextualizados en la administración de empresas.
#
# ---
#
# ## 2. Resultados de aprendizaje
#
# Al finalizar la sesión, el estudiante será capaz de:
#
# 1. Reconocer el ecosistema digital usado en análisis de datos empresariales (Python, Colab, VS Code).
# 2. Ejecutar código en Google Colab y en VS Code.
# 3. Comprender la sintaxis básica de Python: variables, tipos de datos, operaciones y entrada/salida.
# 4. Resolver ejercicios simples aplicados a contextos administrativos (costos, ingresos, inventarios).
# 5. Interpretar resultados numéricos como apoyo a la toma de decisiones.
#
# ---
#
# ## 3. Saberes a desarrollar
#
# ### Conceptuales
#
# * Ecosistema digital: Python, notebooks, editores de código.
# * Variables y tipos de datos.
# * Operaciones aritméticas y lógicas.
# * Entrada y salida de datos.
#
# ### Procedimentales
#
# * Crear y ejecutar notebooks en Colab.
# * Escribir scripts en VS Code.
# * Implementar cálculos empresariales con Python.
#
# ### Actitudinales
#
# * Disposición al aprendizaje tecnológico.
# * Curiosidad por experimentar con datos.
# * Trabajo autónomo y colaborativo.
#
# ---
#
# ## 4. Contenidos
#
# ### 4.1 Ecosistema digital
#
# * ¿Qué es Python y para qué se usa en administración?
# * Ciencia de datos y analítica empresarial.
# * Google Colab vs VS Code: diferencias y usos.
#
# ### 4.2 Sintaxis básica de Python
#
# * Variables
# * Tipos de datos:
#
#   * enteros
#   * flotantes
#   * cadenas
# * Operadores:
#
#   * suma, resta, multiplicación, división
# * print() y input()
#
# ### 4.3 Aplicaciones empresariales iniciales
#
# * Cálculo de costos
# * Cálculo de ingresos
# * Utilidad
# * Precio de venta
#
# ---
#
# ## 5. Secuencia didáctica
#
# ### 5.1 Apertura (30 min)
#
# **Actividad motivadora:**
#
# * Pregunta detonante:
#   *¿Cómo toman decisiones hoy las empresas con datos?*
# * Presentación breve:
#
#   * Python en finanzas, marketing, logística.
#   * Ejemplos reales:
#
#     * predicción de ventas
#     * análisis de clientes
#     * control de inventarios
#
# **Exploración guiada:**
#
# * Abrir Google Colab.
# * Ejecutar primer código:
#
# ```python
# print("Hola, mundo empresarial con Python")
# ```
#
# ---
#
# ### 5.2 Desarrollo (2 horas)
#
# #### Bloque 1: Ecosistema digital (30 min)
#
# * Crear notebook en Colab.
# * Explicar estructura:
#
#   * celdas
#   * ejecución
# * Introducción a VS Code:
#
#   * interfaz
#   * archivo .py
#
# ---
#
# #### Bloque 2: Sintaxis básica (45 min)
#
# **Ejemplo guiado:**
#
# ```python
# # Variables empresariales
# costo = 50000
# precio_venta = 80000
#
# utilidad = precio_venta - costo
#
# print("La utilidad es:", utilidad)
# ```
#
# Conceptos:
#
# * asignación
# * operaciones
# * salida
#
# ---
#
# #### Bloque 3: Ejercicios aplicados a administración (45 min)
#
# ### Ejercicio 1: Cálculo de ingresos
#
# ```python
# precio = 25000
# cantidad_vendida = 120
#
# ingresos = precio * cantidad_vendida
# print("Ingresos totales:", ingresos)
# ```
#
# ---
#
# ### Ejercicio 2: Utilidad de un producto
#
# ```python
# costo_unitario = 18000
# precio_venta = 30000
# unidades = 200
#
# utilidad_total = (precio_venta - costo_unitario) * unidades
# print("Utilidad total:", utilidad_total)
# ```
#
# ---
#
# ### Ejercicio 3: Punto de equilibrio (simple)
#
# ```python
# costos_fijos = 500000
# precio = 20000
# costo_variable = 12000
#
# punto_equilibrio = costos_fijos / (precio - costo_variable)
# print("Unidades para no tener pérdidas:", punto_equilibrio)
# ```
#
# ---
#
# ### Ejercicio 4: Presupuesto empresarial
#
# ```python
# ventas = float(input("Ingrese ventas mensuales: "))
# gastos = float(input("Ingrese gastos mensuales: "))
#
# resultado = ventas - gastos
#
# print("Resultado financiero:", resultado)
# ```
#
# ---
#
# ### 5.3 Cierre (30 min)
#
# **Discusión reflexiva:**
#
# * ¿Qué decisiones puede apoyar Python en una empresa?
# * ¿Qué diferencia hay entre usar Excel y Python?
#
# **Actividad final:**
# Mini-reto:
#
# > Una empresa vende tres productos.
# > Crear un programa que calcule ingresos totales.
#
# ---
#
# ## 6. Evaluación
#
# ### Diagnóstica
#
# * Manejo previo de herramientas digitales.
#
# ### Formativa
#
# * Ejecución de códigos.
# * Participación en ejercicios.
#
# ### Sumativa (salida rápida)
#
# Programa que:
#
# * solicite datos
# * calcule utilidad
# * muestre resultados
#
# ---
#
# ## 7. Recursos
#
# * Google Colab
# * VS Code
# * Computador con internet
# * Proyector
# * Notebook guía
#
# ---
#
# ## 8. Tarea para clase invertida
#
# 1. Crear cuenta en GitHub.
# 2. Ver video:
#
#    * ¿Qué es Python en negocios?
# 3. Resolver:
#
# ```python
# # Calcular salario mensual
# horas = 160
# pago_hora = 12000
#
# salario = horas * pago_hora
# print(salario)
# ```
#
# ---
#
# ## 9. Proyección del curso
#
# Esta clase conecta con:
#
# * Análisis de datos empresariales
# * Estadística con Python
# * Visualización de datos
# * Machine learning para negocios
#
# ---
#
# Si quieres, puedo prepararte también:
#
# 1. El cuaderno Jupyter (.ipynb) listo para usar en clase.
# 2. Una rúbrica de evaluación.
# 3. Una secuencia de 3 clases siguientes (variables → estructuras → análisis de datos empresariales).
# 4. Versión alineada con tu metodología de aula invertida y pensamiento computacional para UdeA.
