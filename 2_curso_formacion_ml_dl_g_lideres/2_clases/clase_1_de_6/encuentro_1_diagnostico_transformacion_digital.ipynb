# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/linear_algebra/blob/main/3_clases_segun_clara_mejia_laverde/3_cap/14_modulo/14_modulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/linear_algebra/blob/main/3_clases_segun_clara_mejia_laverde/3_cap/14_modulo/14_modulo.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # Encuentro 1: Diagnóstico y Transformación Digital
#
# **Curso:** Desarrollo de habilidades digitales en Administración
#
# **Fecha:** Jueves 12 de febrero de 2026
# **Horario:** 6:00 PM – 8:30 PM
#
# ---
#
# ## Propósito del encuentro
# Identificar el nivel inicial de habilidades digitales de los participantes y contextualizar la importancia de la transformación digital en la administración de empresas.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Reconocer la importancia de las competencias digitales en la administración.
# - Identificar el nivel inicial de habilidades digitales mediante un diagnóstico.
# - Comprender el concepto de transformación digital y su impacto en la toma de decisiones empresariales.

# %% [markdown]
# ## Actividad 1. Presentación y contextualización
#
# Discusión guiada:
#
# - ¿Qué herramientas digitales utilizas actualmente?
# - ¿Cómo influyen los datos en la toma de decisiones en las empresas?
# - ¿Qué entiendes por transformación digital?

# %% [markdown]
# ## Actividad 2. Encuesta diagnóstica de habilidades digitales
#
# Responde el siguiente instrumento inicial.

# %%
# Diagnóstico básico de habilidades digitales

preguntas = {
    "1. Nivel de manejo de hojas de cálculo (1-5)": None,
    "2. Nivel de uso de herramientas de visualización de datos (1-5)": None,
    "3. Nivel de programación en Python (1-5)": None,
    "4. Nivel de uso de plataformas colaborativas (Drive, GitHub, etc.) (1-5)": None,
    "5. Nivel de comprensión del análisis de datos (1-5)": None
}

for pregunta in preguntas:
    print(pregunta)

# %% [markdown]
# ## Actividad 3. Conceptualización: Transformación digital
#
# La transformación digital implica la adopción estratégica de tecnologías digitales para redefinir procesos organizacionales, generar valor y mejorar la toma de decisiones basada en datos.

# %% [markdown]
# ## Actividad 4. Discusión aplicada
#
# Analiza el siguiente caso:
#
# Una empresa local toma decisiones basadas únicamente en la intuición del gerente. No utiliza datos históricos ni herramientas tecnológicas.
#
# **Preguntas orientadoras:**
# - ¿Qué riesgos existen?
# - ¿Qué herramientas digitales podrían mejorar este proceso?
# - ¿Qué tipo de datos serían relevantes?

# %% [markdown]
# ## Actividad 5. Reflexión final
#
# Escribe brevemente:
#
# - ¿Qué habilidades digitales necesitas fortalecer?
# - ¿Cómo crees que este curso aportará a tu perfil profesional?

# %%
# Espacio para reflexiones escritas por el estudiante
reflexion = ""
