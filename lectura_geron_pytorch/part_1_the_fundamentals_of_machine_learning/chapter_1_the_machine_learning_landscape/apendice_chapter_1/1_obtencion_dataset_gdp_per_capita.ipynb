# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/5_ml_dl_g_lideres/blob/main/lectura_geron_pytorch/part_1_the_fundamentals_of_machine_learning/chapter_1_the_machine_learning_landscape/apendice_chapter_1/1_obtencion_dataset_gdp_per_capita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/5_ml_dl_g_lideres/blob/main/lectura_geron_pytorch/part_1_the_fundamentals_of_machine_learning/chapter_1_the_machine_learning_landscape/apendice_chapter_1/1_obtencion_dataset_gdp_per_capita.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# Esta es **una explicación completa** de
#
# * los *datasets* que usa Géron en el capítulo 1 de *Hands-On Machine Learning with Scikit-Learn and Pytorch*, de
# * qué significan sus columnas y
# * **cómo obtener versiones más completas desde las fuentes originales**.

# %% [markdown]
# # 1. ¿Qué son los *datasets* de Géron?

# %% [markdown]
# # [*oecd_bli.csv*](https://data-explorer.oecd.org/) Aquí llegara a OECD Data Explorer.

# %% [markdown]
# * Este archivo contiene datos del **OECD Better Life Index (Índice para una Vida Mejor)**, un conjunto de indicadores socioeconómicos que miden aspectos del bienestar en países miembros y asociados de la OCDE. ([Wikipedia](https://en.wikipedia.org/wiki/OECD_Better_Life_Index))

# %% [markdown]
# * Se usa en el libro para extraer la variable **Life satisfaction** (satisfacción con la vida) de cada país. ([Obtenga estos datos oecd_bli.csv](https://www.oecd.org/en/data/indicators.html?orderBy=mostRelevant&page=0&facetTags=oecd-languages%3Aen%2Coecd-policy-areas%3Apa14))

# %%
# el script para filtrar solos life_satisfaction per country
import pandas as pd 
# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('oecd_bli.csv')
# Filtrar las columnas 'Country name' y 'Ladder score'
filtered_df = df[['Country', 'Life satisfaction']]      
# Guardar el DataFrame filtrado en un nuevo archivo CSV
filtered_df.to_csv('life_satisfaction_per_country.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 # Cargar el archivo CSV en un DataFrame
# ----> 4 df = pd.read_csv('oecd_bli.csv')
#       5 # Filtrar las columnas 'Country name' y 'Ladder score'
#       6 filtered_df = df[['Country', 'Life satisfaction']]
#
# ...

# %% [markdown]
# * En el CSV original de Géron hay varias columnas como:
#
#   * `"LOCATION"` o `"Country"` — identificador del país. ([momodel.cn][3])

# %%
# Cómo leer el el dataset y luego ver la columna Location o Country
import pandas as pd 
ubicacion = r"C:\Users\marco\OneDrive - Universidad de Antioquia\Documentos\2_recursos_ensenanza\5_ml_dl_g_lideres\lectura_geron_pytorch\part_1_the_fundamentals_of_machine_learning\chapter_1_the_machine_learning_landscape\apendice_chapter_1\datasets\ocde\oecd_bli.csv"
df = pd.read_csv(ubicacion)
df.columns
# Out:
# Index(['LOCATION', 'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure',
#        'INEQUALITY', 'Inequality', 'Unit Code', 'Unit', 'PowerCode Code',
#        'PowerCode', 'Reference Period Code', 'Reference Period', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df.Country
# Out:
# 0            Australia
# 1              Austria
# 2              Belgium
# 3               Canada
# 4       Czech Republic
#              ...
# 2364         Lithuania
# 2365          Colombia
# 2366         Lithuania
# 2367          Colombia
# 2368         Lithuania
# Name: Country, Length: 2369, dtype: object

# %% [markdown]
#   * `"Indicator"` — el nombre de la medida socio-económica (por ejemplo, *Life satisfaction*). ([momodel.cn][3])

# %%
# Cómo seleccionar de la columna Indicator Name solo los valores que sean "Life satisfaction"
import pandas as pd
df.INDICATOR.value_counts()
# Out:
# INDICATOR
# ES_STCS      200
# HS_SFRH      182
# SC_SNTWS     168
# SW_LIFS      168
# JE_LMIS      162
# PS_FSAFEN    123
# HS_LEB       123
# EQ_WATER     123
# JE_EMPL      123
# PS_REPH      123
# ES_EDUA      120
# ES_EDUEX     120
# JE_LTUR      117
# WL_EWLH      117
# WL_TNOW       69
# EQ_AIRP       41
# CG_VOTO       41
# HO_HISH       39
# CG_SENG       39
# HO_BASE       38
# HO_NUMR       38
# JE_PEARN      36
# IW_HADI       30
# IW_HNFW       29
# Name: count, dtype: int64

# %% [markdown]
#   * `"Value"` — valor numérico del indicador para ese país. ([momodel.cn][3])

# %%
df.Value
# Out:
# 0        5.40
# 1        3.50
# 2        3.70
# 3        6.00
# 4        3.10
#         ...
# 2364     0.54
# 2365    32.09
# 2366     0.67
# 2367    19.37
# 2368     0.43
# Name: Value, Length: 2369, dtype: float64

# %% [markdown]
#   * `"INEQUALITY"` — muestra si el dato es para toda la población o un segmento; en el libro se filtra con `"TOT"` para “Total”. ([Medium][4])

# %%
df.INEQUALITY.value_counts()
# Out:
# INEQUALITY
# TOT    911
# MN     578
# WMN    578
# HGH    164
# LW     138
# Name: count, dtype: int64

# %% [markdown]
#   * Otras columnas: unidad de medida, periodo de referencia, códigos internos, etc. ([momodel.cn][3])

# %% [markdown]
# **Concepto:** El *Better Life Index* agrupa indicadores de bienestar — como educación, medio ambiente, ingresos, comunidad, salud, etc. — organizados en 11 dimensiones por la OCDE que buscan ir más allá del PIB como medida del progreso.

# %%
len(df.columns)
# Out:
# 17

# %% [markdown]
# # [*gdp_per_capita.csv*](https://www.oecd.org/en/data/indicators/nominal-gross-domestic-product-gdp.html)

# %% [markdown]
# * Este archivo representa los datos de **GDP per capita (PIB per cápita)** para cada país — es decir, el valor total de bienes y servicios producidos por persona en un año, típicamente en USD o una medida similar. ([GitHub](https://github.com/ageron/data/tree/main/lifesat))

# %% [markdown]
# * En el notebook del libro, esta tabla se usa para asociar **PIB per cápita** con los valores de *Life satisfaction* para cada país. ([notebook de Géron](https://github.com/ageron/handson-mlp/blob/main/01_the_machine_learning_landscape.ipynb))

# %% [markdown]
# * Sus columnas fundamentales son:
#
#   * `"Country"` — nombre del país. ([GitHub][5])
#   * Una columna (como `"GDP per capita"`) con el valor del PIB per persona para ese año.

# %% [markdown]
#   * Posiblemente otras columnas con años o atributos si el dataset original tiene múltiples años.

# %% [markdown]
# **Concepto:** El PIB per cápita es una medida convencional de nivel de vida que representa la riqueza promedio de un país.
#
# ---

# %% [markdown]
# # 2. ¿Cómo obtener estos datos desde su **fuente original**?

# %% [markdown]
# ## Órigen y descarga del *Better Life Index*

# %% [markdown]
# La OCDE publica sus datos de bienestar, incluidos los indicadores del *Better Life Index*, en su plataforma [*OECD Data Explorer*](https://data-explorer.oecd.org/).

# %% [markdown]
# Puedes descargar datos de bienestar por país en múltiples indicadores directamente desde la web oficial de la OCDE bajo el tópico *Well-being and beyond GDP*. ([OECD][8])

# %% [markdown]
# # **Buscarlo en:**

# %% [markdown]
# * [OECD Data Explorer](https://stats.oecd.org) ➝ Dataset code: **BLI** (Better Life Index) ([about.gitlab.com][9])

# %% [markdown]
# # Datos de GDP per capita desde fuentes completas

# %% [markdown]
# Los datos de PIB per cápita no tienen un único “origen” universal, pues se recopilan por varias instituciones; sin embargo, dos fuentes ampliamente reconocidas son:

# %% [markdown]
# # **World Bank – World Development Indicators**

# %% [markdown]
# * Ofrece series de PIB per cápita para todos los países del mundo, históricas (desde 1960). ([Our World in Data](https://data.worldbank.org/indicator/NY.GDP.PCAP.CD?end=2024&start=1960&view=map))

# %% [markdown]
# * Se puede descargar desde: [GDP per capita](https://data.worldbank.org/indicator/NY.GDP.PCAP.CD)

# %% [markdown]
# # **Our World in Data / Kaggle u otros repositorios**

# %% [markdown]
# * Muchos repositorios (como *OurWorldInData* y datasets de Kaggle) compilan y publican estos datos en formatos CSV con múltiples años y países. ([kaggle.com][10])

# %% [markdown]
# # **Bases alternativas**
#
# * *Penn World Table* para comparaciones internacionales de PIB per capita en términos constantes. ([Wikipedia][11])
#
# ---

# %% [markdown]
# # 3. Diseño de una actividad en Jupyter para **obtener y explorar estos datasets**

# %% [markdown]
# # Título: *Obtención y Exploración de Datos: PIB per Cápita y Satisfacción de Vida en Países*
#
# ---

# %% [markdown]
# ## Bloque 1 — Introducción (Markdown)

# %% [markdown]
# **Objetivo**

# %% [markdown]
# > Aprender a descargar datos socioeconómicos desde fuentes públicas, combinarlos y analizarlos experimentalmente en Python.
# > Incluye:
#
# * Descarga automática de datos.
# * Carga y entendimiento de estructuras de datos.
# * Exploración básica y visualizaciones.
#
# ---

# %% [markdown]
# ## Bloque 2 — Instalación de dependencias y configuración (Code)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Creación del Directorio para datos
data_dir = Path("datasets/ocde")
data_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Bloque 3 — Descarga de los archivos desde GitHub (Code)

# %%
import urllib.request

root = "https://github.com/ageron/data/raw/main/lifesat/"

for fname in ("oecd_bli.csv", "gdp_per_capita.csv"):
    out_path = data_dir / fname
    if not out_path.is_file():
        print(f"Descargando {fname}...")
        urllib.request.urlretrieve(root + fname, out_path)
print("Descargas completadas.")
# Out:
# Descargando oecd_bli.csv...
# Descargando gdp_per_capita.csv...
# Descargas completadas.

# %% [markdown]
# # Bloque 4 — Carga inicial y vista de columnas (Code)

# %%
oecd_bli = pd.read_csv(data_dir/"oecd_bli.csv")
gdp = pd.read_csv(data_dir/"gdp_per_capita.csv", delimiter=',', encoding='latin1', na_values="n/a")

print("Primeras filas de oecd_bli:")
display(oecd_bli.head())

print("Primeras filas de GDP per capita:")
display(gdp.head())
# Out:
# Primeras filas de oecd_bli:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value  Flag Codes  Flags
# ...

# %% [markdown]
# ## Bloque 5 — Entendimiento de atributos (Markdown + Code)

# %% [markdown]
# **Preguntas de investigación:**
#
# * ¿Qué significan las columnas?
# * ¿Qué países están presentes?
# * ¿Qué año traen los datos del GDP per capita?
#
# Luego ejecuta:

# %%
oecd_bli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LOCATION               2369 non-null   object
#  1   Country                2369 non-null   object
#  2   INDICATOR              2369 non-null   object
#  3   Indicator              2369 non-null   object
#  4   MEASURE                2369 non-null   object
#  5   Measure                2369 non-null   object
#  6   INEQUALITY             2369 non-null   object
#  7   Inequality             2369 non-null   object
#  8   Unit Code              2369 non-null   object
#  9   Unit                   2369 non-null   object
#  10  PowerCode Code         2369 non-null   int64
#  11  PowerCode              2369 non-null   object
#  12  Reference Period Code  0 non-null      float64
#  13  Reference Period       0 non-null      float64
# ...

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 4 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Entity                                               7109 non-null   object
#  1   Code                                                 5729 non-null   object
#  2   Year                                                 7109 non-null   int64
#  3   GDP per capita, PPP (constant 2017 international $)  7109 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 222.3+ KB

# %% [markdown]
# # Bloque 6 — Filtrado y pivot para Life Satisfaction (Code)

# %%
# Filtrar desigualdad total
oecd_bli_tot = oecd_bli[oecd_bli["INEQUALITY"] == "TOT"]

# Elegir solo Life satisfaction
oecd_life = oecd_bli_tot[oecd_bli_tot["Indicator"] == "Life satisfaction"][["Country", "Value"]]
oecd_life.rename(columns={"Value":"Life satisfaction"}, inplace=True)

oecd_life.head()
# Out:
#              Country  Life satisfaction
# 1813       Australia                7.3
# 1814         Austria                7.1
# 1815         Belgium                6.9
# 1816          Canada                7.4
# 1817  Czech Republic                6.7

# %% [markdown]
# # Bloque 7 — Extraer y renombrar PIB per cápita (Code)

# %%
gdp.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'GDP per capita, PPP (constant 2017 international $)'],
#       dtype='object')

# %%
# Renombrar la columna Entity 
gdp.rename(columns = {'Entity': 'Country'})
gdp_pc = gdp[["Country","GDP per capita"]]

gdp_pc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Asumir que la columna 2015 existe o renombrarla
# ----> 2 gdp.rename(columns = {'Entity': 'Country'})
#       3 gdp_pc = gdp[["Country","GDP per capita"]]
#       5 gdp_pc.head()
#
# NameError: name 'gdp' is not defined

# %%
gdp.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'GDP per capita, PPP (constant 2017 international $)'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## Bloque 8 — Uniendo datasets (Code)

# %%
country_stats = pd.merge(oecd_life, gdp_pc, on="Country")
display(country_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 country_stats = pd.merge(oecd_life, gdp_pc, on="Country")
#       2 display(country_stats)
#
# NameError: name 'gdp_pc' is not defined

# %% [markdown]
# ### 📉 Bloque 9 — Exploración visual (Code)
#
# ```python
# country_stats.plot(kind="scatter",
#                    x="GDP per capita",
#                    y="Life satisfaction",
#                    title="Relación entre PIB per cápita y Vida Satisfaction")
# plt.show()
# ```
#
# ---

# %% [markdown]
# ### 📎 Bloque 10 — Reflexión y conclusiones (Markdown)
#
# **Preguntas clave:**
#
# * ¿Existe correlación entre renta promedio y satisfacción de vida?
# * ¿Qué países destacan por encima o por debajo de la tendencia?
#
# ---

# %% [markdown]
# ## 🧩 Extensiones posibles
#
# ➡️ Obtener el **PIB per cápita mundial** completo desde la API del *World Bank* y compararlo con el PIB de la OCDE. ([Our World in Data][7])
# ➡️ Añadir otras variables disponibles de *Better Life Index*: educación, salud, empleo, etc.
#
# ---

# %% [markdown]
# Si quieres, también puedo **transformar este diseño en un `.ipynb` listo para usar o publicar en GitHub**, o agregarte la **versión para análisis temporal (varios años)** usando los datos del Banco Mundial u Our World in Data.
#
# [1]: https://en.wikipedia.org/wiki/OECD_Better_Life_Index?utm_source=chatgpt.com "OECD Better Life Index"
# [2]: https://codingalzi.github.io/datapy/pandas_oecd_bli.html?utm_source=chatgpt.com "31. OECD 국가의 삶의 만족도 — 파이썬 데이터 분석"
# [3]: https://momodel.cn/repo/YKCEDGkzhmuddtIoqoONJrtFLnJXnfugLtPufMWmH-nY6Jw%3D/blob/master/datasets/lifesat/oecd_bli_2015.csv?utm_source=chatgpt.com "datasets/lifesat/oecd_bli_2015.csv - hands-on-machine-learning (master) - Mo Repos"
# [4]: https://medium.com/analytics-vidhya/hands-on-machine-learning-simple-linear-regres-c9bdf0b58549?utm_source=chatgpt.com "Hands-On Machine Learning — Simple Linear Regression"
# [5]: https://github.com/ageron/handson-ml/blob/master/datasets/lifesat/gdp_per_capita.csv?utm_source=chatgpt.com "handson-ml/datasets/lifesat/gdp_per_capita.csv at master"
# [6]: https://notebook.community/ageron/handson-ml2/01_the_machine_learning_landscape?utm_source=chatgpt.com "| notebook.community"
# [7]: https://pages.owid.io/grapher/gdp-per-capita-worldbank?utm_source=chatgpt.com "GDP per capita - Our World in Data"
# [8]: https://www.oecd.org/en/data/tools/oecd-better-life-index.html?utm_source=chatgpt.com "OECD Well-being Data Monitor | OECD"
# [9]: https://gitlab.com/shankarpandala/Hands-on-Machine-Learning-practice/tree/master/datasets/lifesat?utm_source=chatgpt.com "datasets/lifesat - Hands-on-Machine-Learning-practice"
# [10]: https://www.kaggle.com/datasets/nitishabharathi/gdp-per-capita-all-countries?utm_source=chatgpt.com "GDP per capita all countries"
# [11]: https://en.wikipedia.org/wiki/Penn_World_Table?utm_source=chatgpt.com "Penn World Table"
